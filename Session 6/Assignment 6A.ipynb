# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(48, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(Convolution2D(48, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(96, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(96, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(192, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(192, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3))`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3))`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3))`
#   app.launch_new_instance()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_9 (Activation)    (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 30, 30, 48)        20784
# _________________________________________________________________
# activation_10 (Activation)   (None, 30, 30, 48)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 15, 15, 48)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 15, 15, 48)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 15, 15, 96)        41568
# _________________________________________________________________
# activation_11 (Activation)   (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 13, 13, 96)        83040
# _________________________________________________________________
# activation_12 (Activation)   (None, 13, 13, 96)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 96)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 6, 6, 96)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 6, 6, 192)         166080
# _________________________________________________________________
# activation_13 (Activation)   (None, 6, 6, 192)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 4, 4, 192)         331968
# _________________________________________________________________
# activation_14 (Activation)   (None, 4, 4, 192)         0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 192)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 2, 2, 192)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 768)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               393728
# _________________________________________________________________
# activation_15 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_16 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,172,410
# Trainable params: 1,172,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=100)`
#   if sys.path[0] == '':
# Epoch 1/100
# 390/390 [==============================] - 10s 25ms/step - loss: 1.8831 - acc: 0.2697 - val_loss: 1.4890 - val_acc: 0.4551
# Epoch 2/100
# 390/390 [==============================] - 9s 22ms/step - loss: 1.3887 - acc: 0.4940 - val_loss: 1.1625 - val_acc: 0.5844
# Epoch 3/100
# 390/390 [==============================] - 9s 22ms/step - loss: 1.1486 - acc: 0.5927 - val_loss: 0.9871 - val_acc: 0.6524
# Epoch 4/100
# 390/390 [==============================] - 9s 23ms/step - loss: 1.0032 - acc: 0.6490 - val_loss: 0.8816 - val_acc: 0.6887
# Epoch 5/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.8948 - acc: 0.6926 - val_loss: 0.7900 - val_acc: 0.7252
# Epoch 6/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.8157 - acc: 0.7202 - val_loss: 0.7171 - val_acc: 0.7573
# Epoch 7/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.7609 - acc: 0.7384 - val_loss: 0.7214 - val_acc: 0.7569
# Epoch 8/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.7198 - acc: 0.7554 - val_loss: 0.6782 - val_acc: 0.7640
# Epoch 9/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.6721 - acc: 0.7723 - val_loss: 0.7090 - val_acc: 0.7581
# Epoch 10/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.6516 - acc: 0.7796 - val_loss: 0.6466 - val_acc: 0.7826
# Epoch 11/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.6225 - acc: 0.7884 - val_loss: 0.6491 - val_acc: 0.7794
# Epoch 12/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5910 - acc: 0.8000 - val_loss: 0.6199 - val_acc: 0.7918
# Epoch 13/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5718 - acc: 0.8051 - val_loss: 0.5976 - val_acc: 0.7976
# Epoch 14/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5536 - acc: 0.8120 - val_loss: 0.6322 - val_acc: 0.7907
# Epoch 15/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5386 - acc: 0.8167 - val_loss: 0.5755 - val_acc: 0.8067
# Epoch 16/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5196 - acc: 0.8246 - val_loss: 0.5898 - val_acc: 0.8055
# Epoch 17/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5022 - acc: 0.8298 - val_loss: 0.5917 - val_acc: 0.8078
# Epoch 18/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4962 - acc: 0.8306 - val_loss: 0.5682 - val_acc: 0.8141
# Epoch 19/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4877 - acc: 0.8336 - val_loss: 0.5918 - val_acc: 0.8071
# Epoch 20/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4724 - acc: 0.8389 - val_loss: 0.5981 - val_acc: 0.8056
# Epoch 21/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4637 - acc: 0.8421 - val_loss: 0.5674 - val_acc: 0.8102
# Epoch 22/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4559 - acc: 0.8442 - val_loss: 0.5985 - val_acc: 0.8055
# Epoch 23/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4527 - acc: 0.8448 - val_loss: 0.6069 - val_acc: 0.7989
# Epoch 24/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4397 - acc: 0.8502 - val_loss: 0.5842 - val_acc: 0.8139
# Epoch 25/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4292 - acc: 0.8544 - val_loss: 0.5889 - val_acc: 0.8130
# Epoch 26/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4245 - acc: 0.8547 - val_loss: 0.6005 - val_acc: 0.8090
# Epoch 27/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4148 - acc: 0.8584 - val_loss: 0.5822 - val_acc: 0.8188
# Epoch 28/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4092 - acc: 0.8625 - val_loss: 0.5703 - val_acc: 0.8153
# Epoch 29/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4035 - acc: 0.8620 - val_loss: 0.5725 - val_acc: 0.8149
# Epoch 30/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3971 - acc: 0.8642 - val_loss: 0.6117 - val_acc: 0.8122
# Epoch 31/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3934 - acc: 0.8673 - val_loss: 0.5777 - val_acc: 0.8233
# Epoch 32/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3876 - acc: 0.8705 - val_loss: 0.5783 - val_acc: 0.8197
# Epoch 33/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3855 - acc: 0.8699 - val_loss: 0.5929 - val_acc: 0.8170
# Epoch 34/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3865 - acc: 0.8701 - val_loss: 0.5689 - val_acc: 0.8213
# Epoch 35/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3753 - acc: 0.8737 - val_loss: 0.5802 - val_acc: 0.8170
# Epoch 36/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3734 - acc: 0.8723 - val_loss: 0.5899 - val_acc: 0.8173
# Epoch 37/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3658 - acc: 0.8764 - val_loss: 0.5919 - val_acc: 0.8248
# Epoch 38/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3590 - acc: 0.8783 - val_loss: 0.5860 - val_acc: 0.8223
# Epoch 39/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3538 - acc: 0.8814 - val_loss: 0.5978 - val_acc: 0.8188
# Epoch 40/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3505 - acc: 0.8833 - val_loss: 0.5892 - val_acc: 0.8184
# Epoch 41/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3486 - acc: 0.8826 - val_loss: 0.5826 - val_acc: 0.8220
# Epoch 42/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3396 - acc: 0.8865 - val_loss: 0.5917 - val_acc: 0.8146
# Epoch 43/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3467 - acc: 0.8844 - val_loss: 0.6002 - val_acc: 0.8225
# Epoch 44/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3434 - acc: 0.8865 - val_loss: 0.5752 - val_acc: 0.8217
# Epoch 45/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3335 - acc: 0.8861 - val_loss: 0.5854 - val_acc: 0.8274
# Epoch 46/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3401 - acc: 0.8855 - val_loss: 0.5962 - val_acc: 0.8175
# Epoch 47/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3288 - acc: 0.8902 - val_loss: 0.5941 - val_acc: 0.8200
# Epoch 48/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3309 - acc: 0.8905 - val_loss: 0.5906 - val_acc: 0.8230
# Epoch 49/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3174 - acc: 0.8939 - val_loss: 0.5977 - val_acc: 0.8282
# Epoch 50/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3248 - acc: 0.8914 - val_loss: 0.5775 - val_acc: 0.8261
# Epoch 51/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3225 - acc: 0.8923 - val_loss: 0.5806 - val_acc: 0.8246
# Epoch 52/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3210 - acc: 0.8947 - val_loss: 0.6242 - val_acc: 0.8147
# Epoch 53/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3088 - acc: 0.8980 - val_loss: 0.6194 - val_acc: 0.8186
# Epoch 54/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3155 - acc: 0.8939 - val_loss: 0.5976 - val_acc: 0.8209
# Epoch 55/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3116 - acc: 0.8957 - val_loss: 0.5856 - val_acc: 0.8321
# Epoch 56/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3098 - acc: 0.8978 - val_loss: 0.5715 - val_acc: 0.8250
# Epoch 57/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3092 - acc: 0.8963 - val_loss: 0.5788 - val_acc: 0.8304
# Epoch 58/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3021 - acc: 0.8989 - val_loss: 0.5821 - val_acc: 0.8326
# Epoch 59/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3040 - acc: 0.8985 - val_loss: 0.5911 - val_acc: 0.8233
# Epoch 60/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2977 - acc: 0.9014 - val_loss: 0.5812 - val_acc: 0.8299
# Epoch 61/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2956 - acc: 0.9030 - val_loss: 0.6235 - val_acc: 0.8185
# Epoch 62/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2977 - acc: 0.9026 - val_loss: 0.6071 - val_acc: 0.8295
# Epoch 63/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2982 - acc: 0.9016 - val_loss: 0.5833 - val_acc: 0.8309
# Epoch 64/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2974 - acc: 0.9033 - val_loss: 0.6067 - val_acc: 0.8265
# Epoch 65/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3033 - acc: 0.9022 - val_loss: 0.5775 - val_acc: 0.8289
# Epoch 66/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2928 - acc: 0.9051 - val_loss: 0.6020 - val_acc: 0.8298
# Epoch 67/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2991 - acc: 0.9031 - val_loss: 0.5962 - val_acc: 0.8332
# Epoch 68/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2851 - acc: 0.9074 - val_loss: 0.5909 - val_acc: 0.8246
# Epoch 69/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2878 - acc: 0.9041 - val_loss: 0.6008 - val_acc: 0.8261
# Epoch 70/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2850 - acc: 0.9068 - val_loss: 0.6076 - val_acc: 0.8333
# Epoch 71/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2830 - acc: 0.9076 - val_loss: 0.5972 - val_acc: 0.8318
# Epoch 72/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2869 - acc: 0.9083 - val_loss: 0.6061 - val_acc: 0.8274
# Epoch 73/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2894 - acc: 0.9085 - val_loss: 0.6128 - val_acc: 0.8262
# Epoch 74/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2800 - acc: 0.9086 - val_loss: 0.6160 - val_acc: 0.8305
# Epoch 75/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2759 - acc: 0.9106 - val_loss: 0.5982 - val_acc: 0.8357
# Epoch 76/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2780 - acc: 0.9101 - val_loss: 0.6116 - val_acc: 0.8294
# Epoch 77/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2689 - acc: 0.9114 - val_loss: 0.6146 - val_acc: 0.8335
# Epoch 78/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2774 - acc: 0.9109 - val_loss: 0.6039 - val_acc: 0.8349
# Epoch 79/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2679 - acc: 0.9130 - val_loss: 0.5947 - val_acc: 0.8324
# Epoch 80/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2708 - acc: 0.9115 - val_loss: 0.6129 - val_acc: 0.8344
# Epoch 81/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2704 - acc: 0.9127 - val_loss: 0.6380 - val_acc: 0.8265
# Epoch 82/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2675 - acc: 0.9152 - val_loss: 0.6490 - val_acc: 0.8237
# Epoch 83/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2732 - acc: 0.9121 - val_loss: 0.6334 - val_acc: 0.8245
# Epoch 84/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2654 - acc: 0.9142 - val_loss: 0.6655 - val_acc: 0.8196
# Epoch 85/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2617 - acc: 0.9164 - val_loss: 0.6373 - val_acc: 0.8220
# Epoch 86/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2656 - acc: 0.9147 - val_loss: 0.6079 - val_acc: 0.8273
# Epoch 87/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2646 - acc: 0.9149 - val_loss: 0.6955 - val_acc: 0.8233
# Epoch 88/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2655 - acc: 0.9146 - val_loss: 0.5908 - val_acc: 0.8353
# Epoch 89/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2628 - acc: 0.9140 - val_loss: 0.6289 - val_acc: 0.8292
# Epoch 90/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2659 - acc: 0.9164 - val_loss: 0.6336 - val_acc: 0.8307
# Epoch 91/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2669 - acc: 0.9150 - val_loss: 0.6231 - val_acc: 0.8285
# Epoch 92/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2675 - acc: 0.9144 - val_loss: 0.5977 - val_acc: 0.8315
# Epoch 93/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2660 - acc: 0.9151 - val_loss: 0.6160 - val_acc: 0.8315
# Epoch 94/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2610 - acc: 0.9174 - val_loss: 0.6385 - val_acc: 0.8325
# Epoch 95/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2633 - acc: 0.9167 - val_loss: 0.6036 - val_acc: 0.8391
# Epoch 96/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2514 - acc: 0.9197 - val_loss: 0.6375 - val_acc: 0.8305
# Epoch 97/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2672 - acc: 0.9168 - val_loss: 0.5899 - val_acc: 0.8289
# Epoch 98/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2534 - acc: 0.9211 - val_loss: 0.6170 - val_acc: 0.8307
# Epoch 99/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2599 - acc: 0.9192 - val_loss: 0.6575 - val_acc: 0.8202
# Epoch 100/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2550 - acc: 0.9189 - val_loss: 0.6358 - val_acc: 0.8285
# Model took 889.11 seconds to train
# Accuracy on test data is: 82.85

# %%
# My Model
# Convolution Block 1
model = Sequential()
model.add(Convolution2D(44, 3, 3, border_mode='same', input_shape=(32, 32, 3))) #32
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Convolution2D(88, 3, 3, border_mode='same')) #30
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Convolution2D(128, 3, 3, border_mode='same')) #28
model.add(BatchNormalization())
model.add(Activation('relu'))

# Transision Block 1

model.add(MaxPooling2D(pool_size=(2, 2))) #14
# model.add(Dropout(0.25))

model.add(Convolution2D(44, 1, 1)) #14
model.add(Activation('relu'))

# Convolution Block 2

model.add(Convolution2D(88, 3, 3, border_mode='same'))#14
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Convolution2D(88, 3, 3, border_mode='same'))#14
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Convolution2D(128, 3, 3, border_mode='same')) #28
model.add(BatchNormalization())
model.add(Activation('relu'))

# Transision Block 2

model.add(MaxPooling2D(pool_size=(2, 2))) #7
# model.add(Dropout(0.25))
model.add(Convolution2D(44, 1, 1)) #7
model.add(Activation('relu'))

# Convolution Block 3

model.add(Convolution2D(44, 3, 3, border_mode='same')) #8
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Convolution2D(88, 3, 3, border_mode='same'))#8
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Convolution2D(128, 3, 3, border_mode='same'))#8
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Convolution2D(10, 1, 1)) #7
model.add(Activation('relu'))

model.add(Convolution2D(10, 8, 8)) 
model.add(Activation('relu'))

model.add(Flatten())
model.add(Activation('softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(44, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(88, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(44, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(88, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(88, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:40: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(44, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:45: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(44, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(88, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:53: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:57: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:60: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8))`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_262 (Conv2D)          (None, 32, 32, 44)        1232
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 44)        176
# _________________________________________________________________
# activation_279 (Activation)  (None, 32, 32, 44)        0
# _________________________________________________________________
# conv2d_263 (Conv2D)          (None, 32, 32, 88)        34936
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 32, 88)        352
# _________________________________________________________________
# activation_280 (Activation)  (None, 32, 32, 88)        0
# _________________________________________________________________
# conv2d_264 (Conv2D)          (None, 32, 32, 128)       101504
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_281 (Activation)  (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_54 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_265 (Conv2D)          (None, 16, 16, 44)        5676
# _________________________________________________________________
# activation_282 (Activation)  (None, 16, 16, 44)        0
# _________________________________________________________________
# conv2d_266 (Conv2D)          (None, 16, 16, 88)        34936
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 88)        352
# _________________________________________________________________
# activation_283 (Activation)  (None, 16, 16, 88)        0
# _________________________________________________________________
# conv2d_267 (Conv2D)          (None, 16, 16, 88)        69784
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16, 16, 88)        352
# _________________________________________________________________
# activation_284 (Activation)  (None, 16, 16, 88)        0
# _________________________________________________________________
# conv2d_268 (Conv2D)          (None, 16, 16, 128)       101504
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_285 (Activation)  (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_55 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_269 (Conv2D)          (None, 8, 8, 44)          5676
# _________________________________________________________________
# activation_286 (Activation)  (None, 8, 8, 44)          0
# _________________________________________________________________
# conv2d_270 (Conv2D)          (None, 8, 8, 44)          17468
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 8, 8, 44)          176
# _________________________________________________________________
# activation_287 (Activation)  (None, 8, 8, 44)          0
# _________________________________________________________________
# conv2d_271 (Conv2D)          (None, 8, 8, 88)          34936
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 88)          352
# _________________________________________________________________
# activation_288 (Activation)  (None, 8, 8, 88)          0
# _________________________________________________________________
# conv2d_272 (Conv2D)          (None, 8, 8, 128)         101504
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# activation_289 (Activation)  (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_273 (Conv2D)          (None, 8, 8, 10)          1290
# _________________________________________________________________
# activation_290 (Activation)  (None, 8, 8, 10)          0
# _________________________________________________________________
# conv2d_274 (Conv2D)          (None, 1, 1, 10)          6410
# _________________________________________________________________
# activation_291 (Activation)  (None, 1, 1, 10)          0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 10)                0
# _________________________________________________________________
# activation_292 (Activation)  (None, 10)                0
# =================================================================
# Total params: 520,152
# Trainable params: 518,504
# Non-trainable params: 1,648
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=100)`
#   if sys.path[0] == '':
# Epoch 1/100
# 390/390 [==============================] - 28s 73ms/step - loss: 1.3646 - acc: 0.5128 - val_loss: 1.4365 - val_acc: 0.5064
# Epoch 2/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.8243 - acc: 0.7099 - val_loss: 1.4091 - val_acc: 0.5580
# Epoch 3/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.6537 - acc: 0.7705 - val_loss: 0.9998 - val_acc: 0.6585
# Epoch 4/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.5479 - acc: 0.8083 - val_loss: 0.9620 - val_acc: 0.6696
# Epoch 5/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.4675 - acc: 0.8389 - val_loss: 0.9733 - val_acc: 0.6801
# Epoch 6/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.4074 - acc: 0.8585 - val_loss: 0.6963 - val_acc: 0.7601
# Epoch 7/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.3480 - acc: 0.8788 - val_loss: 0.7401 - val_acc: 0.7543
# Epoch 8/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.2973 - acc: 0.8969 - val_loss: 0.7549 - val_acc: 0.7641
# Epoch 9/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.2555 - acc: 0.9109 - val_loss: 0.6673 - val_acc: 0.8035
# Epoch 10/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.2167 - acc: 0.9247 - val_loss: 0.7182 - val_acc: 0.7908
# Epoch 11/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.1822 - acc: 0.9365 - val_loss: 0.6832 - val_acc: 0.7976
# Epoch 12/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.1606 - acc: 0.9433 - val_loss: 0.7776 - val_acc: 0.7912
# Epoch 13/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.1368 - acc: 0.9526 - val_loss: 0.7577 - val_acc: 0.7982
# Epoch 14/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.1133 - acc: 0.9610 - val_loss: 1.0015 - val_acc: 0.7760
# Epoch 15/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.1050 - acc: 0.9639 - val_loss: 1.0113 - val_acc: 0.7645
# Epoch 16/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0979 - acc: 0.9655 - val_loss: 1.0313 - val_acc: 0.7655
# Epoch 17/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0874 - acc: 0.9689 - val_loss: 1.0001 - val_acc: 0.7867
# Epoch 18/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0853 - acc: 0.9707 - val_loss: 0.9815 - val_acc: 0.7869
# Epoch 19/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0694 - acc: 0.9754 - val_loss: 0.9427 - val_acc: 0.7901
# Epoch 20/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0758 - acc: 0.9743 - val_loss: 1.0512 - val_acc: 0.7881
# Epoch 21/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.0678 - acc: 0.9761 - val_loss: 1.0477 - val_acc: 0.7800
# Epoch 22/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0626 - acc: 0.9788 - val_loss: 1.0652 - val_acc: 0.7857
# Epoch 23/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0626 - acc: 0.9777 - val_loss: 1.3625 - val_acc: 0.7468
# Epoch 24/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0526 - acc: 0.9813 - val_loss: 1.4033 - val_acc: 0.7430
# Epoch 25/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0641 - acc: 0.9773 - val_loss: 1.0001 - val_acc: 0.8013
# Epoch 26/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0475 - acc: 0.9832 - val_loss: 1.3415 - val_acc: 0.7693
# Epoch 27/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0477 - acc: 0.9835 - val_loss: 1.2731 - val_acc: 0.7785
# Epoch 28/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0539 - acc: 0.9808 - val_loss: 1.0513 - val_acc: 0.7964
# Epoch 29/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0457 - acc: 0.9842 - val_loss: 0.8894 - val_acc: 0.8181
# Epoch 30/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0489 - acc: 0.9828 - val_loss: 1.1132 - val_acc: 0.7959
# Epoch 31/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0436 - acc: 0.9847 - val_loss: 0.9055 - val_acc: 0.8186
# Epoch 32/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0422 - acc: 0.9855 - val_loss: 1.3852 - val_acc: 0.7572
# Epoch 33/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0355 - acc: 0.9879 - val_loss: 1.1197 - val_acc: 0.7995
# Epoch 34/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0397 - acc: 0.9862 - val_loss: 0.9790 - val_acc: 0.8212
# Epoch 35/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0426 - acc: 0.9850 - val_loss: 1.1344 - val_acc: 0.8044
# Epoch 36/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0410 - acc: 0.9861 - val_loss: 0.9994 - val_acc: 0.8173
# Epoch 37/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0311 - acc: 0.9894 - val_loss: 1.2711 - val_acc: 0.7858
# Epoch 38/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0402 - acc: 0.9862 - val_loss: 1.0311 - val_acc: 0.8138
# Epoch 39/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0319 - acc: 0.9889 - val_loss: 1.2582 - val_acc: 0.7825
# Epoch 40/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0372 - acc: 0.9869 - val_loss: 1.0268 - val_acc: 0.7990
# Epoch 41/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0363 - acc: 0.9880 - val_loss: 1.1895 - val_acc: 0.7827
# Epoch 42/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0324 - acc: 0.9888 - val_loss: 1.0743 - val_acc: 0.8128
# Epoch 43/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0298 - acc: 0.9893 - val_loss: 1.0555 - val_acc: 0.8157
# Epoch 44/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0348 - acc: 0.9882 - val_loss: 1.3681 - val_acc: 0.7786
# Epoch 45/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0354 - acc: 0.9878 - val_loss: 1.0472 - val_acc: 0.8161
# Epoch 46/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0312 - acc: 0.9892 - val_loss: 1.2215 - val_acc: 0.7934
# Epoch 47/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0255 - acc: 0.9910 - val_loss: 1.5835 - val_acc: 0.7529
# Epoch 48/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0303 - acc: 0.9892 - val_loss: 1.2969 - val_acc: 0.7939
# Epoch 49/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0341 - acc: 0.9879 - val_loss: 1.1242 - val_acc: 0.8119
# Epoch 50/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0244 - acc: 0.9921 - val_loss: 1.3129 - val_acc: 0.7902
# Epoch 51/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0253 - acc: 0.9910 - val_loss: 1.1270 - val_acc: 0.8125
# Epoch 52/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0287 - acc: 0.9896 - val_loss: 1.1290 - val_acc: 0.8101
# Epoch 53/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0242 - acc: 0.9918 - val_loss: 1.1954 - val_acc: 0.8057
# Epoch 54/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0311 - acc: 0.9894 - val_loss: 1.0906 - val_acc: 0.8151
# Epoch 55/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0270 - acc: 0.9906 - val_loss: 1.2245 - val_acc: 0.7978
# Epoch 56/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0241 - acc: 0.9918 - val_loss: 1.3246 - val_acc: 0.7827
# Epoch 57/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0243 - acc: 0.9911 - val_loss: 1.2029 - val_acc: 0.7946
# Epoch 58/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0258 - acc: 0.9910 - val_loss: 1.0515 - val_acc: 0.8251
# Epoch 59/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0181 - acc: 0.9937 - val_loss: 1.1763 - val_acc: 0.8083
# Epoch 60/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0267 - acc: 0.9905 - val_loss: 1.2419 - val_acc: 0.7974
# Epoch 61/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0165 - acc: 0.9943 - val_loss: 1.4465 - val_acc: 0.7659
# Epoch 62/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0291 - acc: 0.9899 - val_loss: 1.3516 - val_acc: 0.7864
# Epoch 63/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0229 - acc: 0.9919 - val_loss: 1.2680 - val_acc: 0.7921
# Epoch 64/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0200 - acc: 0.9928 - val_loss: 1.1243 - val_acc: 0.8089
# Epoch 65/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0215 - acc: 0.9926 - val_loss: 1.1289 - val_acc: 0.8174
# Epoch 66/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0258 - acc: 0.9908 - val_loss: 1.1412 - val_acc: 0.8173
# Epoch 67/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0206 - acc: 0.9927 - val_loss: 1.3081 - val_acc: 0.8084
# Epoch 68/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0136 - acc: 0.9953 - val_loss: 1.2714 - val_acc: 0.8128
# Epoch 69/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0184 - acc: 0.9937 - val_loss: 1.1454 - val_acc: 0.8086
# Epoch 70/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0300 - acc: 0.9905 - val_loss: 1.3094 - val_acc: 0.8072
# Epoch 71/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0178 - acc: 0.9939 - val_loss: 1.1915 - val_acc: 0.8158
# Epoch 72/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0193 - acc: 0.9933 - val_loss: 1.2110 - val_acc: 0.8100
# Epoch 73/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0210 - acc: 0.9931 - val_loss: 1.4317 - val_acc: 0.7971
# Epoch 74/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0220 - acc: 0.9923 - val_loss: 1.1523 - val_acc: 0.8261
# Epoch 75/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0198 - acc: 0.9937 - val_loss: 1.4251 - val_acc: 0.7944
# Epoch 76/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0122 - acc: 0.9958 - val_loss: 1.1523 - val_acc: 0.8288
# Epoch 77/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0222 - acc: 0.9920 - val_loss: 1.2170 - val_acc: 0.8098
# Epoch 78/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0153 - acc: 0.9945 - val_loss: 1.2291 - val_acc: 0.8070
# Epoch 79/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0185 - acc: 0.9935 - val_loss: 1.2950 - val_acc: 0.8072
# Epoch 80/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.0152 - acc: 0.9947 - val_loss: 1.4104 - val_acc: 0.7998
# Epoch 81/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.0264 - acc: 0.9909 - val_loss: 1.2133 - val_acc: 0.8144
# Epoch 82/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.0136 - acc: 0.9955 - val_loss: 1.1848 - val_acc: 0.8210
# Epoch 83/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0125 - acc: 0.9957 - val_loss: 1.2142 - val_acc: 0.8220
# Epoch 84/100
# 390/390 [==============================] - 25s 64ms/step - loss: 0.0201 - acc: 0.9929 - val_loss: 1.1326 - val_acc: 0.8215
# Epoch 85/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0197 - acc: 0.9934 - val_loss: 1.1429 - val_acc: 0.8227
# Epoch 86/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0237 - acc: 0.9924 - val_loss: 1.3252 - val_acc: 0.7866
# Epoch 87/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0156 - acc: 0.9951 - val_loss: 1.1122 - val_acc: 0.8316
# Epoch 88/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0171 - acc: 0.9943 - val_loss: 1.2051 - val_acc: 0.8178
# Epoch 89/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0147 - acc: 0.9953 - val_loss: 1.2234 - val_acc: 0.8077
# Epoch 90/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0183 - acc: 0.9935 - val_loss: 1.4692 - val_acc: 0.7952
# Epoch 91/100
# 390/390 [==============================] - 24s 63ms/step - loss: 0.0148 - acc: 0.9954 - val_loss: 1.1523 - val_acc: 0.8243
# Epoch 92/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0117 - acc: 0.9960 - val_loss: 1.2118 - val_acc: 0.8172
# Epoch 93/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0198 - acc: 0.9930 - val_loss: 1.2509 - val_acc: 0.8184
# Epoch 94/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0176 - acc: 0.9940 - val_loss: 1.2564 - val_acc: 0.8051
# Epoch 95/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0144 - acc: 0.9955 - val_loss: 1.2285 - val_acc: 0.8150
# Epoch 96/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0128 - acc: 0.9956 - val_loss: 1.1521 - val_acc: 0.8245
# Epoch 97/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0117 - acc: 0.9957 - val_loss: 1.1808 - val_acc: 0.8265
# Epoch 98/100
# 390/390 [==============================] - 24s 63ms/step - loss: 0.0189 - acc: 0.9937 - val_loss: 1.3258 - val_acc: 0.8128
# Epoch 99/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0197 - acc: 0.9935 - val_loss: 1.1903 - val_acc: 0.8156
# Epoch 100/100
# 390/390 [==============================] - 25s 63ms/step - loss: 0.0144 - acc: 0.9949 - val_loss: 1.3831 - val_acc: 0.8034
# Model took 2469.68 seconds to train
# Accuracy on test data is: 80.34

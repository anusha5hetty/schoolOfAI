# %% [markdown]
# Importing required Libraries

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Getting CIFAR10 dataset

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 9s 0us/step

# %% [markdown]
# Plotting an image of each class using pyplot

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# Method to plot model history

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# Method to get test accuracy

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# ## Base Model

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(48, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(Convolution2D(48, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(96, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(96, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(192, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(192, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3))`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3))`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3))`
#   app.launch_new_instance()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 48)        20784
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 48)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 48)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 48)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 96)        41568
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 96)        83040
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 96)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 96)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 96)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 192)         166080
# _________________________________________________________________
# activation_5 (Activation)    (None, 6, 6, 192)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 192)         331968
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 4, 192)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 192)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 192)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 768)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               393728
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,172,410
# Trainable params: 1,172,410
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the base model
#
# Test Accuracy: 82.85

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=100)`
#   if sys.path[0] == '':
# Epoch 1/100
# 390/390 [==============================] - 10s 25ms/step - loss: 1.8831 - acc: 0.2697 - val_loss: 1.4890 - val_acc: 0.4551
# Epoch 2/100
# 390/390 [==============================] - 9s 22ms/step - loss: 1.3887 - acc: 0.4940 - val_loss: 1.1625 - val_acc: 0.5844
# Epoch 3/100
# 390/390 [==============================] - 9s 22ms/step - loss: 1.1486 - acc: 0.5927 - val_loss: 0.9871 - val_acc: 0.6524
# Epoch 4/100
# 390/390 [==============================] - 9s 23ms/step - loss: 1.0032 - acc: 0.6490 - val_loss: 0.8816 - val_acc: 0.6887
# Epoch 5/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.8948 - acc: 0.6926 - val_loss: 0.7900 - val_acc: 0.7252
# Epoch 6/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.8157 - acc: 0.7202 - val_loss: 0.7171 - val_acc: 0.7573
# Epoch 7/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.7609 - acc: 0.7384 - val_loss: 0.7214 - val_acc: 0.7569
# Epoch 8/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.7198 - acc: 0.7554 - val_loss: 0.6782 - val_acc: 0.7640
# Epoch 9/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.6721 - acc: 0.7723 - val_loss: 0.7090 - val_acc: 0.7581
# Epoch 10/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.6516 - acc: 0.7796 - val_loss: 0.6466 - val_acc: 0.7826
# Epoch 11/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.6225 - acc: 0.7884 - val_loss: 0.6491 - val_acc: 0.7794
# Epoch 12/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5910 - acc: 0.8000 - val_loss: 0.6199 - val_acc: 0.7918
# Epoch 13/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5718 - acc: 0.8051 - val_loss: 0.5976 - val_acc: 0.7976
# Epoch 14/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5536 - acc: 0.8120 - val_loss: 0.6322 - val_acc: 0.7907
# Epoch 15/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5386 - acc: 0.8167 - val_loss: 0.5755 - val_acc: 0.8067
# Epoch 16/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5196 - acc: 0.8246 - val_loss: 0.5898 - val_acc: 0.8055
# Epoch 17/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5022 - acc: 0.8298 - val_loss: 0.5917 - val_acc: 0.8078
# Epoch 18/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4962 - acc: 0.8306 - val_loss: 0.5682 - val_acc: 0.8141
# Epoch 19/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4877 - acc: 0.8336 - val_loss: 0.5918 - val_acc: 0.8071
# Epoch 20/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4724 - acc: 0.8389 - val_loss: 0.5981 - val_acc: 0.8056
# Epoch 21/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4637 - acc: 0.8421 - val_loss: 0.5674 - val_acc: 0.8102
# Epoch 22/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4559 - acc: 0.8442 - val_loss: 0.5985 - val_acc: 0.8055
# Epoch 23/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4527 - acc: 0.8448 - val_loss: 0.6069 - val_acc: 0.7989
# Epoch 24/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4397 - acc: 0.8502 - val_loss: 0.5842 - val_acc: 0.8139
# Epoch 25/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4292 - acc: 0.8544 - val_loss: 0.5889 - val_acc: 0.8130
# Epoch 26/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4245 - acc: 0.8547 - val_loss: 0.6005 - val_acc: 0.8090
# Epoch 27/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4148 - acc: 0.8584 - val_loss: 0.5822 - val_acc: 0.8188
# Epoch 28/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4092 - acc: 0.8625 - val_loss: 0.5703 - val_acc: 0.8153
# Epoch 29/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4035 - acc: 0.8620 - val_loss: 0.5725 - val_acc: 0.8149
# Epoch 30/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3971 - acc: 0.8642 - val_loss: 0.6117 - val_acc: 0.8122
# Epoch 31/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3934 - acc: 0.8673 - val_loss: 0.5777 - val_acc: 0.8233
# Epoch 32/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3876 - acc: 0.8705 - val_loss: 0.5783 - val_acc: 0.8197
# Epoch 33/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3855 - acc: 0.8699 - val_loss: 0.5929 - val_acc: 0.8170
# Epoch 34/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3865 - acc: 0.8701 - val_loss: 0.5689 - val_acc: 0.8213
# Epoch 35/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3753 - acc: 0.8737 - val_loss: 0.5802 - val_acc: 0.8170
# Epoch 36/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3734 - acc: 0.8723 - val_loss: 0.5899 - val_acc: 0.8173
# Epoch 37/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3658 - acc: 0.8764 - val_loss: 0.5919 - val_acc: 0.8248
# Epoch 38/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3590 - acc: 0.8783 - val_loss: 0.5860 - val_acc: 0.8223
# Epoch 39/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3538 - acc: 0.8814 - val_loss: 0.5978 - val_acc: 0.8188
# Epoch 40/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3505 - acc: 0.8833 - val_loss: 0.5892 - val_acc: 0.8184
# Epoch 41/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3486 - acc: 0.8826 - val_loss: 0.5826 - val_acc: 0.8220
# Epoch 42/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3396 - acc: 0.8865 - val_loss: 0.5917 - val_acc: 0.8146
# Epoch 43/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3467 - acc: 0.8844 - val_loss: 0.6002 - val_acc: 0.8225
# Epoch 44/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3434 - acc: 0.8865 - val_loss: 0.5752 - val_acc: 0.8217
# Epoch 45/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3335 - acc: 0.8861 - val_loss: 0.5854 - val_acc: 0.8274
# Epoch 46/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3401 - acc: 0.8855 - val_loss: 0.5962 - val_acc: 0.8175
# Epoch 47/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3288 - acc: 0.8902 - val_loss: 0.5941 - val_acc: 0.8200
# Epoch 48/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3309 - acc: 0.8905 - val_loss: 0.5906 - val_acc: 0.8230
# Epoch 49/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3174 - acc: 0.8939 - val_loss: 0.5977 - val_acc: 0.8282
# Epoch 50/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3248 - acc: 0.8914 - val_loss: 0.5775 - val_acc: 0.8261
# Epoch 51/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3225 - acc: 0.8923 - val_loss: 0.5806 - val_acc: 0.8246
# Epoch 52/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3210 - acc: 0.8947 - val_loss: 0.6242 - val_acc: 0.8147
# Epoch 53/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3088 - acc: 0.8980 - val_loss: 0.6194 - val_acc: 0.8186
# Epoch 54/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3155 - acc: 0.8939 - val_loss: 0.5976 - val_acc: 0.8209
# Epoch 55/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3116 - acc: 0.8957 - val_loss: 0.5856 - val_acc: 0.8321
# Epoch 56/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3098 - acc: 0.8978 - val_loss: 0.5715 - val_acc: 0.8250
# Epoch 57/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3092 - acc: 0.8963 - val_loss: 0.5788 - val_acc: 0.8304
# Epoch 58/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3021 - acc: 0.8989 - val_loss: 0.5821 - val_acc: 0.8326
# Epoch 59/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3040 - acc: 0.8985 - val_loss: 0.5911 - val_acc: 0.8233
# Epoch 60/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2977 - acc: 0.9014 - val_loss: 0.5812 - val_acc: 0.8299
# Epoch 61/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2956 - acc: 0.9030 - val_loss: 0.6235 - val_acc: 0.8185
# Epoch 62/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2977 - acc: 0.9026 - val_loss: 0.6071 - val_acc: 0.8295
# Epoch 63/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2982 - acc: 0.9016 - val_loss: 0.5833 - val_acc: 0.8309
# Epoch 64/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2974 - acc: 0.9033 - val_loss: 0.6067 - val_acc: 0.8265
# Epoch 65/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3033 - acc: 0.9022 - val_loss: 0.5775 - val_acc: 0.8289
# Epoch 66/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2928 - acc: 0.9051 - val_loss: 0.6020 - val_acc: 0.8298
# Epoch 67/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2991 - acc: 0.9031 - val_loss: 0.5962 - val_acc: 0.8332
# Epoch 68/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2851 - acc: 0.9074 - val_loss: 0.5909 - val_acc: 0.8246
# Epoch 69/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2878 - acc: 0.9041 - val_loss: 0.6008 - val_acc: 0.8261
# Epoch 70/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2850 - acc: 0.9068 - val_loss: 0.6076 - val_acc: 0.8333
# Epoch 71/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2830 - acc: 0.9076 - val_loss: 0.5972 - val_acc: 0.8318
# Epoch 72/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2869 - acc: 0.9083 - val_loss: 0.6061 - val_acc: 0.8274
# Epoch 73/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2894 - acc: 0.9085 - val_loss: 0.6128 - val_acc: 0.8262
# Epoch 74/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2800 - acc: 0.9086 - val_loss: 0.6160 - val_acc: 0.8305
# Epoch 75/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2759 - acc: 0.9106 - val_loss: 0.5982 - val_acc: 0.8357
# Epoch 76/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2780 - acc: 0.9101 - val_loss: 0.6116 - val_acc: 0.8294
# Epoch 77/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2689 - acc: 0.9114 - val_loss: 0.6146 - val_acc: 0.8335
# Epoch 78/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2774 - acc: 0.9109 - val_loss: 0.6039 - val_acc: 0.8349
# Epoch 79/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2679 - acc: 0.9130 - val_loss: 0.5947 - val_acc: 0.8324
# Epoch 80/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2708 - acc: 0.9115 - val_loss: 0.6129 - val_acc: 0.8344
# Epoch 81/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2704 - acc: 0.9127 - val_loss: 0.6380 - val_acc: 0.8265
# Epoch 82/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2675 - acc: 0.9152 - val_loss: 0.6490 - val_acc: 0.8237
# Epoch 83/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2732 - acc: 0.9121 - val_loss: 0.6334 - val_acc: 0.8245
# Epoch 84/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2654 - acc: 0.9142 - val_loss: 0.6655 - val_acc: 0.8196
# Epoch 85/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2617 - acc: 0.9164 - val_loss: 0.6373 - val_acc: 0.8220
# Epoch 86/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2656 - acc: 0.9147 - val_loss: 0.6079 - val_acc: 0.8273
# Epoch 87/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2646 - acc: 0.9149 - val_loss: 0.6955 - val_acc: 0.8233
# Epoch 88/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2655 - acc: 0.9146 - val_loss: 0.5908 - val_acc: 0.8353
# Epoch 89/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2628 - acc: 0.9140 - val_loss: 0.6289 - val_acc: 0.8292
# Epoch 90/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2659 - acc: 0.9164 - val_loss: 0.6336 - val_acc: 0.8307
# Epoch 91/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2669 - acc: 0.9150 - val_loss: 0.6231 - val_acc: 0.8285
# Epoch 92/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2675 - acc: 0.9144 - val_loss: 0.5977 - val_acc: 0.8315
# Epoch 93/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2660 - acc: 0.9151 - val_loss: 0.6160 - val_acc: 0.8315
# Epoch 94/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2610 - acc: 0.9174 - val_loss: 0.6385 - val_acc: 0.8325
# Epoch 95/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2633 - acc: 0.9167 - val_loss: 0.6036 - val_acc: 0.8391
# Epoch 96/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2514 - acc: 0.9197 - val_loss: 0.6375 - val_acc: 0.8305
# Epoch 97/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2672 - acc: 0.9168 - val_loss: 0.5899 - val_acc: 0.8289
# Epoch 98/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2534 - acc: 0.9211 - val_loss: 0.6170 - val_acc: 0.8307
# Epoch 99/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2599 - acc: 0.9192 - val_loss: 0.6575 - val_acc: 0.8202
# Epoch 100/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2550 - acc: 0.9189 - val_loss: 0.6358 - val_acc: 0.8285
# Model took 889.11 seconds to train
# Accuracy on test data is: 82.85

# %% [markdown]
# ## My Model

# %%
# Convolution Block 1
model = Sequential()
model.add(Convolution2D(24, 3, 3, border_mode='same', input_shape=(32, 32, 3))) #32, RF: 3
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Convolution2D(72, 3, 3, border_mode='same')) #32, RF: 5
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))


model.add(Convolution2D(144, 3, 3, border_mode='same')) #32, RF: 7
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))


# Transision Block 1

model.add(MaxPooling2D(pool_size=(2, 2))) #16, RF: 14
# model.add(Dropout(0.25))

model.add(Convolution2D(24, 1, 1)) #16, RF: 14
model.add(Activation('relu'))

model.add(Dropout(0.1))

# Convolution Block 2

model.add(Convolution2D(72, 3, 3, border_mode='same'))#16, RF: 16
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))


model.add(Convolution2D(72, 3, 3, border_mode='same'))#16, RF: 18
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))


# Transision Block 2

model.add(MaxPooling2D(pool_size=(2, 2))) #8, RF: 36
# model.add(Dropout(0.25))
model.add(Convolution2D(24, 1, 1)) #8, RF: 36
model.add(Activation('relu'))
model.add(Dropout(0.1))


# Convolution Block 3

model.add(Convolution2D(24, 3, 3, border_mode='same')) #8, RF: 38
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))


model.add(Convolution2D(72, 3, 3, border_mode='same'))#8, RF: 40
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))


model.add(Convolution2D(144, 3, 3, border_mode='same'))#8, RF: 42
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))


model.add(Convolution2D(10, 1, 1)) #8, RF: 42
model.add(Activation('relu'))

model.add(Convolution2D(10, 8, 8)) #1x1x10


model.add(Flatten())
model.add(Activation('softmax'))

# Compile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(72, (3, 3), padding="same")`
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(144, (3, 3), padding="same")`
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(72, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(72, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:54: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(24, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:60: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(72, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:66: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(144, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:72: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:75: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8))`

# %%
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.003), metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_55 (Conv2D)           (None, 32, 32, 24)        672
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 32, 32, 24)        96
# _________________________________________________________________
# activation_58 (Activation)   (None, 32, 32, 24)        0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 32, 32, 24)        0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 32, 32, 72)        15624
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 32, 32, 72)        288
# _________________________________________________________________
# activation_59 (Activation)   (None, 32, 32, 72)        0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 32, 32, 72)        0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 32, 32, 144)       93456
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 32, 32, 144)       576
# _________________________________________________________________
# activation_60 (Activation)   (None, 32, 32, 144)       0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 32, 32, 144)       0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 144)       0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 16, 16, 24)        3480
# _________________________________________________________________
# activation_61 (Activation)   (None, 16, 16, 24)        0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 16, 16, 24)        0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 16, 16, 72)        15624
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 16, 16, 72)        288
# _________________________________________________________________
# activation_62 (Activation)   (None, 16, 16, 72)        0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 16, 16, 72)        0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 16, 16, 72)        46728
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 16, 16, 72)        288
# _________________________________________________________________
# activation_63 (Activation)   (None, 16, 16, 72)        0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 16, 16, 72)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 8, 72)          0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 8, 8, 24)          1752
# _________________________________________________________________
# activation_64 (Activation)   (None, 8, 8, 24)          0
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 8, 8, 24)          0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 8, 8, 24)          5208
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 8, 8, 24)          96
# _________________________________________________________________
# activation_65 (Activation)   (None, 8, 8, 24)          0
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 8, 8, 24)          0
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 8, 8, 72)          15624
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 8, 8, 72)          288
# _________________________________________________________________
# activation_66 (Activation)   (None, 8, 8, 72)          0
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 8, 8, 72)          0
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 8, 8, 144)         93456
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 8, 8, 144)         576
# _________________________________________________________________
# activation_67 (Activation)   (None, 8, 8, 144)         0
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 8, 8, 144)         0
# _________________________________________________________________
# conv2d_65 (Conv2D)           (None, 8, 8, 10)          1450
# _________________________________________________________________
# activation_68 (Activation)   (None, 8, 8, 10)          0
# _________________________________________________________________
# conv2d_66 (Conv2D)           (None, 1, 1, 10)          6410
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_69 (Activation)   (None, 10)                0
# =================================================================
# Total params: 301,980
# Trainable params: 300,732
# Non-trainable params: 1,248
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), callbacks=[LearningRateScheduler(scheduler, verbose=1)])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
#   if sys.path[0] == '':
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 390/390 [==============================] - 34s 88ms/step - loss: 1.5465 - acc: 0.4317 - val_loss: 1.6620 - val_acc: 0.4476
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0022744503.
# 390/390 [==============================] - 30s 76ms/step - loss: 1.1051 - acc: 0.6050 - val_loss: 1.2133 - val_acc: 0.5741
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0018315018.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.9251 - acc: 0.6701 - val_loss: 0.9716 - val_acc: 0.6508
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0015329586.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.8172 - acc: 0.7074 - val_loss: 1.1098 - val_acc: 0.6059
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0013181019.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.7373 - acc: 0.7380 - val_loss: 0.9462 - val_acc: 0.6740
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0011560694.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.6730 - acc: 0.7606 - val_loss: 1.0133 - val_acc: 0.6580
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0010295127.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.6193 - acc: 0.7813 - val_loss: 0.7740 - val_acc: 0.7375
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0009279307.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.5832 - acc: 0.7934 - val_loss: 0.7195 - val_acc: 0.7519
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0008445946.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.5468 - acc: 0.8071 - val_loss: 0.6330 - val_acc: 0.7838
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0007749935.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.5198 - acc: 0.8164 - val_loss: 0.6446 - val_acc: 0.7808
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0007159905.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4940 - acc: 0.8249 - val_loss: 0.6175 - val_acc: 0.7950
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.000665336.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4761 - acc: 0.8312 - val_loss: 0.6009 - val_acc: 0.7984
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0006213753.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.4521 - acc: 0.8413 - val_loss: 0.6452 - val_acc: 0.7821
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005828638.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4378 - acc: 0.8439 - val_loss: 0.5835 - val_acc: 0.8035
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005488474.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4173 - acc: 0.8510 - val_loss: 0.7183 - val_acc: 0.7670
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005185825.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.4014 - acc: 0.8576 - val_loss: 0.7846 - val_acc: 0.7528
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.000491481.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3923 - acc: 0.8605 - val_loss: 0.5826 - val_acc: 0.8060
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0004670715.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3835 - acc: 0.8634 - val_loss: 0.5724 - val_acc: 0.8073
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0004449718.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3733 - acc: 0.8666 - val_loss: 0.5387 - val_acc: 0.8218
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.000424869.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3596 - acc: 0.8734 - val_loss: 0.6067 - val_acc: 0.8014
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0004065041.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3553 - acc: 0.8757 - val_loss: 0.6233 - val_acc: 0.7966
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.000389661.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3452 - acc: 0.8784 - val_loss: 0.5651 - val_acc: 0.8163
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0003741581.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.3337 - acc: 0.8820 - val_loss: 0.5910 - val_acc: 0.8084
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0003598417.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3281 - acc: 0.8827 - val_loss: 0.5455 - val_acc: 0.8245
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0003465804.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3201 - acc: 0.8856 - val_loss: 0.5691 - val_acc: 0.8162
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0003342618.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.3128 - acc: 0.8884 - val_loss: 0.5615 - val_acc: 0.8169
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0003227889.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3073 - acc: 0.8905 - val_loss: 0.5696 - val_acc: 0.8200
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0003120774.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.3041 - acc: 0.8906 - val_loss: 0.5790 - val_acc: 0.8141
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.000302054.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2996 - acc: 0.8925 - val_loss: 0.5701 - val_acc: 0.8206
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0002926544.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2965 - acc: 0.8938 - val_loss: 0.5356 - val_acc: 0.8315
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0002838221.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2880 - acc: 0.8979 - val_loss: 0.5659 - val_acc: 0.8218
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0002755074.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.2825 - acc: 0.8997 - val_loss: 0.5908 - val_acc: 0.8151
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.000267666.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2766 - acc: 0.9018 - val_loss: 0.5732 - val_acc: 0.8224
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0002602585.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.2745 - acc: 0.9004 - val_loss: 0.5363 - val_acc: 0.8328
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.00025325.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2701 - acc: 0.9040 - val_loss: 0.5638 - val_acc: 0.8265
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0002466091.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2686 - acc: 0.9030 - val_loss: 0.5566 - val_acc: 0.8273
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0002403076.
# 390/390 [==============================] - 29s 75ms/step - loss: 0.2675 - acc: 0.9051 - val_loss: 0.5695 - val_acc: 0.8246
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0002343201.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.2580 - acc: 0.9079 - val_loss: 0.5524 - val_acc: 0.8288
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0002286237.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2553 - acc: 0.9081 - val_loss: 0.5615 - val_acc: 0.8254
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0002231977.
# 390/390 [==============================] - 29s 75ms/step - loss: 0.2532 - acc: 0.9081 - val_loss: 0.5697 - val_acc: 0.8252
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0002180233.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2491 - acc: 0.9109 - val_loss: 0.5392 - val_acc: 0.8307
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0002130833.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.2464 - acc: 0.9108 - val_loss: 0.5481 - val_acc: 0.8329
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0002083623.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2412 - acc: 0.9133 - val_loss: 0.5789 - val_acc: 0.8255
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0002038459.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2393 - acc: 0.9130 - val_loss: 0.6004 - val_acc: 0.8205
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0001995211.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2395 - acc: 0.9131 - val_loss: 0.6052 - val_acc: 0.8184
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0001953761.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2366 - acc: 0.9157 - val_loss: 0.5308 - val_acc: 0.8368
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001913998.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2334 - acc: 0.9164 - val_loss: 0.5952 - val_acc: 0.8202
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0001875821.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2355 - acc: 0.9152 - val_loss: 0.5503 - val_acc: 0.8340
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0001839137.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2263 - acc: 0.9184 - val_loss: 0.5827 - val_acc: 0.8257
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.000180386.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2287 - acc: 0.9169 - val_loss: 0.5573 - val_acc: 0.8315
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001769912.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2226 - acc: 0.9202 - val_loss: 0.5440 - val_acc: 0.8352
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001737217.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2205 - acc: 0.9203 - val_loss: 0.5997 - val_acc: 0.8225
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001705708.
# 390/390 [==============================] - 29s 75ms/step - loss: 0.2184 - acc: 0.9212 - val_loss: 0.5693 - val_acc: 0.8314
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001675322.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2163 - acc: 0.9214 - val_loss: 0.5368 - val_acc: 0.8382
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001646.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2176 - acc: 0.9208 - val_loss: 0.5660 - val_acc: 0.8293
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001617687.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2136 - acc: 0.9224 - val_loss: 0.6047 - val_acc: 0.8201
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001590331.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.2105 - acc: 0.9234 - val_loss: 0.6088 - val_acc: 0.8211
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001563885.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2136 - acc: 0.9233 - val_loss: 0.6241 - val_acc: 0.8175
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001538304.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.2063 - acc: 0.9245 - val_loss: 0.5899 - val_acc: 0.8267
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001513546.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2049 - acc: 0.9260 - val_loss: 0.5503 - val_acc: 0.8381
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001489573.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2035 - acc: 0.9273 - val_loss: 0.5764 - val_acc: 0.8330
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001466347.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2049 - acc: 0.9254 - val_loss: 0.5757 - val_acc: 0.8289
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001443835.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2022 - acc: 0.9270 - val_loss: 0.5814 - val_acc: 0.8287
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001422003.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2001 - acc: 0.9270 - val_loss: 0.6081 - val_acc: 0.8238
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001400822.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1993 - acc: 0.9281 - val_loss: 0.5779 - val_acc: 0.8341
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001380262.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.2007 - acc: 0.9285 - val_loss: 0.6060 - val_acc: 0.8248
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001360297.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1988 - acc: 0.9281 - val_loss: 0.5861 - val_acc: 0.8310
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001340902.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1909 - acc: 0.9311 - val_loss: 0.5720 - val_acc: 0.8313
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001322052.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1958 - acc: 0.9294 - val_loss: 0.5485 - val_acc: 0.8373
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001303724.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1910 - acc: 0.9311 - val_loss: 0.5575 - val_acc: 0.8355
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.0001285898.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1904 - acc: 0.9307 - val_loss: 0.5918 - val_acc: 0.8302
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.0001268553.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1867 - acc: 0.9312 - val_loss: 0.6029 - val_acc: 0.8262
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.0001251669.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.1911 - acc: 0.9307 - val_loss: 0.5512 - val_acc: 0.8399
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.0001235229.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1869 - acc: 0.9319 - val_loss: 0.5928 - val_acc: 0.8314
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.0001219215.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1859 - acc: 0.9326 - val_loss: 0.5962 - val_acc: 0.8300
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.0001203611.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1837 - acc: 0.9343 - val_loss: 0.5776 - val_acc: 0.8342
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.0001188401.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1819 - acc: 0.9344 - val_loss: 0.5558 - val_acc: 0.8403
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.0001173571.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.1845 - acc: 0.9332 - val_loss: 0.5746 - val_acc: 0.8373
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.0001159107.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.1828 - acc: 0.9334 - val_loss: 0.6008 - val_acc: 0.8286
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.0001144994.
# 390/390 [==============================] - 29s 75ms/step - loss: 0.1819 - acc: 0.9329 - val_loss: 0.5777 - val_acc: 0.8318
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.0001131222.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1817 - acc: 0.9333 - val_loss: 0.5687 - val_acc: 0.8360
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.0001117776.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1785 - acc: 0.9346 - val_loss: 0.5878 - val_acc: 0.8334
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.0001104647.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.1773 - acc: 0.9361 - val_loss: 0.5839 - val_acc: 0.8334
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.0001091822.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1774 - acc: 0.9359 - val_loss: 0.5753 - val_acc: 0.8354
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.0001079292.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1719 - acc: 0.9369 - val_loss: 0.5896 - val_acc: 0.8356
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.0001067046.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.1756 - acc: 0.9360 - val_loss: 0.5839 - val_acc: 0.8339
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.0001055075.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1732 - acc: 0.9371 - val_loss: 0.5814 - val_acc: 0.8354
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.0001043369.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1712 - acc: 0.9378 - val_loss: 0.5976 - val_acc: 0.8315
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.0001031921.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1722 - acc: 0.9369 - val_loss: 0.5827 - val_acc: 0.8366
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.0001020721.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1736 - acc: 0.9363 - val_loss: 0.5865 - val_acc: 0.8366
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.0001009761.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1711 - acc: 0.9381 - val_loss: 0.5927 - val_acc: 0.8316
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler setting learning rate to 9.99034e-05.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1679 - acc: 0.9390 - val_loss: 0.5794 - val_acc: 0.8355
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler setting learning rate to 9.88533e-05.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1663 - acc: 0.9390 - val_loss: 0.5802 - val_acc: 0.8357
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler setting learning rate to 9.7825e-05.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1697 - acc: 0.9377 - val_loss: 0.5977 - val_acc: 0.8329
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler setting learning rate to 9.68179e-05.
# 390/390 [==============================] - 29s 76ms/step - loss: 0.1660 - acc: 0.9398 - val_loss: 0.5958 - val_acc: 0.8338
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler setting learning rate to 9.58313e-05.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1657 - acc: 0.9392 - val_loss: 0.6095 - val_acc: 0.8285
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler setting learning rate to 9.48647e-05.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1673 - acc: 0.9389 - val_loss: 0.5836 - val_acc: 0.8372
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler setting learning rate to 9.39173e-05.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1674 - acc: 0.9385 - val_loss: 0.6109 - val_acc: 0.8324
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler setting learning rate to 9.29887e-05.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1597 - acc: 0.9415 - val_loss: 0.5771 - val_acc: 0.8395
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler setting learning rate to 9.20782e-05.
# 390/390 [==============================] - 30s 76ms/step - loss: 0.1616 - acc: 0.9404 - val_loss: 0.5849 - val_acc: 0.8385
# Model took 2962.58 seconds to train
# Accuracy on test data is: 83.85
